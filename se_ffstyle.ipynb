# %% [markdown]
# # Sbooks — Shaden Enterprises Operations Platform
# ## SE FF-Style: Project Tracking & Session Management
#
# **Created:** 2026-03-22
# **Tech Stack:** FastAPI + SQLModel + PostgreSQL (Neon) + React Native + FastHTML + Modal
#
# ---
#
# ### Supporting Files
# | File | Purpose |
# |------|---------|
# | `PROGRESS.md` | Project progress tracker — phases, sprint checklist, session log |
# | `SESSION_PRACTICES.md` | Industry standard tracking & cleanup practices |

# %% [markdown]
# ---
# ## 1. Progress Tracking Options
#
# | Approach | When to Use |
# |----------|------------|
# | **`PROGRESS.md` in repo** | Solo dev / small team, keeps tracking close to code |
# | **GitHub Issues + Projects board** | Kanban/sprint boards, assignees, labels — free and integrated with repo |
# | **Linear / Jira / Notion** | Team settings, more structure, sprint velocity tracking |
# | **CHANGELOG.md** | For tracking *releases*, not dev progress — different purpose |
#
# **Current choice for Sbooks:** `PROGRESS.md` in repo

# %% [markdown]
# ---
# ## 2. End-of-Session Cleanup (Industry Standard)
#
# What good developers do before closing the laptop:
#
# **Commit WIP:**
# ```bash
# git add -A && git commit -m "WIP: description of where I left off"
# ```
# Never leave uncommitted work overnight.
#
# **Push to remote:** Protects against local machine failure.
#
# **Update your tracker:** 2 minutes of session notes saves 20 minutes of "where was I?" next time.
#
# **Clean up branches:**
# ```bash
# git branch --merged | grep -v main | xargs git branch -d
# ```
#
# **Close running servers/processes:** Avoid port conflicts next session.
#
# **Leave a breadcrumb:** `# TODO: NEXT SESSION - ...` comment at the exact line you stopped.

# %% [markdown]
# ---
# ## 3. Structured Approaches (For When the Project Grows)
#
# **GitHub Issues as Sprint Items**
# - One issue per sprint task, close as you go
# - Use milestones for sprints — gives you a free Kanban board
#
# **Git Stash with Messages**
# ```bash
# git stash push -m "halfway through auth middleware"
# ```
# When you don't want WIP commits polluting history.
#
# **ADR (Architecture Decision Records)**
# ```
# /docs/decisions/001-chose-neon-over-supabase.md
# ```
# Tracks *why* you made choices — invaluable months later.
#
# **Conventional Commits**
# ```
# feat(auth): add JWT token refresh endpoint
# fix(inventory): correct stock count on partial delivery
# chore(deps): update fastapi to 0.109.0
# ```
# Structured messages that enable automated changelogs.
#
# **Pre-commit Hooks** — Automate quality checks: linting, formatting, type checking, secret scanning.

# %% [markdown]
# ---
# ## Current Project Status Snapshot (Updated: 2026-03-24)
#
# **Where we are:** Phase 3 — Architecture & Design (wrapping up) → Phase 4 Sprint 1 next
#
# **What's done:**
# - Full business discovery & 10 workflows documented
# - 41-table data model fully specified across 8 clusters
# - Role-access matrix for 4 roles (Salesperson, Stock Manager, Business Manager, Owner)
# - MVP scope: 25 tables Phase 1, 16 deferred to Phase 2
# - 9-sprint development plan
# - Project scaffolding created & pushed to GitHub
#
# **GitHub Issues Status (2026-03-24):**
# - Session 2 auto-created 7 issues, 5 labels, 1 milestone — but this was done without user permission
# - Session 3: decided to delete everything and have user recreate manually
# - Deletion commands provided; user will run them and recreate issues using `gh` CLI
#
# **What's empty:** All code files (`main.py`, `database.py`, models, routers, core)
#
# **What's next:**
# 1. Delete auto-created GitHub Issues, milestone, labels
# 2. Manually recreate Sprint 1 issues via `gh` CLI
# 3. Start coding: `.gitignore` → `requirements.txt` → `database.py` → `main.py`
#
# ---
# *Full details in `PROGRESS.md` | Practices reference in `SESSION_PRACTICES.md`*
